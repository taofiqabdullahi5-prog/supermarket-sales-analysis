# %% [markdown]
# <a href="https://colab.research.google.com/github/taofiqabdullahi5-prog/supermarket-sales-analysis/blob/main/Supermarket_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/taofiqabdullahi5-prog/supermarket-sales-analysis.git
# Out:
# Cloning into 'supermarket-sales-analysis'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 11 (delta 0), reused 11 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), done.

# %%
import pandas as pd
df = pd.read_csv("supermarket-sales-analysis/data/supermarket_sales.csv")
print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
